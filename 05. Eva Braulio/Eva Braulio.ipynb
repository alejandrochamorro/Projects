# %%
initial_num = '+44(0)731177281'

# %%
# lista = []
# for i in range(10):
#     for n in range(7,16):
#         #print (n, i)
#         numero = initial_num[0:n]+'{}'.format(i)+initial_num[n:]
#         print(numero)
#         lista.append(numero)

# %%
len(lista)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-708f5d2ee923> in <module>
# ----> 1 len(lista)
#
# NameError: name 'lista' is not defined

# %%
initial_num_0 = '+44(0)731177281'
initial_num = '+44(0)73117728'
lista = []
for x in range(10):
    n_2 = initial_num+str(x)
    for i in range(10):
        for n in range(7,16):
#            print (n, i)
            numero = n_2[0:n]+'{}'.format(i)+n_2[n:]
            print(numero)
            lista.append(numero)
# Out:
# +44(0)7031177280
# +44(0)7301177280
# +44(0)7310177280
# +44(0)7311077280
# +44(0)7311707280
# +44(0)7311770280
# +44(0)7311772080
# +44(0)7311772800
# +44(0)7311772800
# +44(0)7131177280
# +44(0)7311177280
# +44(0)7311177280
# +44(0)7311177280
# +44(0)7311717280
# +44(0)7311771280
# +44(0)7311772180
# +44(0)7311772810
# +44(0)7311772801
# +44(0)7231177280
# +44(0)7321177280
# +44(0)7312177280
# +44(0)7311277280
# +44(0)7311727280
# +44(0)7311772280
# +44(0)7311772280
# +44(0)7311772820
# +44(0)7311772802
# +44(0)7331177280
# +44(0)7331177280
# +44(0)7313177280
# +44(0)7311377280
# +44(0)7311737280
# +44(0)7311773280
# +44(0)7311772380
# +44(0)7311772830
# +44(0)7311772803
# +44(0)7431177280
# +44(0)7341177280
# +44(0)7314177280
# +44(0)7311477280
# +44(0)7311747280
# +44(0)7311774280
# +44(0)7311772480
# +44(0)7311772840
# +44(0)7311772804
# +44(0)7531177280
# +44(0)7351177280
# +44(0)7315177280
# +44(0)7311577280
# +44(0)7311757280
# +44(0)7311775280
# +44(0)7311772580
# ...

# %%
len(lista)
# Out:
# 900

# %%
initial_num = '+44(0)731177281'
lista = []
for i in range(10):
    for n in range(7,16):
        #print (n, i)
        numero = initial_num[0:n]+'{}'.format(i)+initial_num[n:]
        print(numero)
        lista.append(numero)
# Out:
# +44(0)7031177281
# +44(0)7301177281
# +44(0)7310177281
# +44(0)7311077281
# +44(0)7311707281
# +44(0)7311770281
# +44(0)7311772081
# +44(0)7311772801
# +44(0)7311772810
# +44(0)7131177281
# +44(0)7311177281
# +44(0)7311177281
# +44(0)7311177281
# +44(0)7311717281
# +44(0)7311771281
# +44(0)7311772181
# +44(0)7311772811
# +44(0)7311772811
# +44(0)7231177281
# +44(0)7321177281
# +44(0)7312177281
# +44(0)7311277281
# +44(0)7311727281
# +44(0)7311772281
# +44(0)7311772281
# +44(0)7311772821
# +44(0)7311772812
# +44(0)7331177281
# +44(0)7331177281
# +44(0)7313177281
# +44(0)7311377281
# +44(0)7311737281
# +44(0)7311773281
# +44(0)7311772381
# +44(0)7311772831
# +44(0)7311772813
# +44(0)7431177281
# +44(0)7341177281
# +44(0)7314177281
# +44(0)7311477281
# +44(0)7311747281
# +44(0)7311774281
# +44(0)7311772481
# +44(0)7311772841
# +44(0)7311772814
# +44(0)7531177281
# +44(0)7351177281
# +44(0)7315177281
# +44(0)7311577281
# +44(0)7311757281
# +44(0)7311775281
# +44(0)7311772581
# ...

# %%
initial_nun = '+346294X429Y'
initial_num = '+346294429'
lista = []
for i in range(10):
    for n in range(10):
        numero = initial_num[0:7]+'{}'.format(i)+initial_num[7:]+'{}'.format(n)
        #print(numero)
        lista.append(numero)

# Numero de combinaciones
numero_de_combinaciones = 'Numero de combinciones: ' + '{}'.format(len(lista))
print(numero_de_combinaciones)
print('\n')

# Imprimir listado
print('Listado de posibles combinaciones:')
print('\n')
print(lista)
# Out:
# Numero de combinciones: 100
#
#
# Listado de posibles combinaciones:
#
#
# ...
