# %%
import pandas as pd

# %%
import sys
'geopandas' in sys.modules
# Out:
# False

# %%
# %matplotlib inline

import seaborn as sns
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-abca345da809> in <module>
#       3 import seaborn as sns
#       4 import pandas as pd
# ----> 5 import geopandas as gpd
#       6 import numpy as np
#       7 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-a62d01c1d62e> in <module>
# ----> 1 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
import pandas as pd

# %%
df = gpd.read_file("data/PARCELA/PARCELA.shp")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8a2f92bce7dc> in <module>
# ----> 1 df = gpd.read_file("data/PARCELA/PARCELA.shp")
#
# NameError: name 'gpd' is not defined

# %%
df.head()
# Out:
#     MAPA  DELEGACIO  MUNICIPIO   MASA     HOJA TIPO PARCELA      COORX  \
# 0  28267         28        900  59850  VK4758F    U      22  445749.81
# 1  28267         28        900  59850  VK4758F    U      23  445745.83
# 2  28267         28        900  65223  VK4762D    U      01  446416.88
# 3  28267         28        900  65223  VK4762D    U      01  446416.80
# 4  28267         28        900  19679  VK4616H    U      03  441604.07
#
#         COORY      VIA  ...  FECHAALTA FECHABAJA     NINTERNO    PCAT1  \
# 0  4478275.61     84.0  ...   20130220  20130513  280113239.0  5985022
# 1  4478250.67   9221.0  ...   20130220  20130513  280113240.0  5985023
# 2  4472079.00   1960.0  ...   20130307  20130307  280705779.0  6522301
# 3  4472079.07   1960.0  ...   20130307  99999999  280706924.0  6522301
# 4  4466408.99  46283.0  ...   20130523  20150512  281860670.0  1967903
#
#      PCAT2  EJERCICIO  NUM_EXP CONTROL          REFCAT  \
# 0  VK4758F       None     None    None  5985022VK4758F
# 1  VK4758F       None     None    None  5985023VK4758F
# 2  VK4762D       None     None    None  6522301VK4762D
# 3  VK4762D       None     None    None  6522301VK4762D
# 4  VK4616H       None     None    None  1967903VK4616H
#
#                                             geometry
# 0  POLYGON ((445726.762 4478263.288, 445727.344 4...
# 1  POLYGON ((445751.268 4478262.563, 445751.476 4...
# 2  POLYGON ((446354.900 4472297.255, 446355.396 4...
# 3  POLYGON ((446311.187 4472177.764, 446312.670 4...
# 4  POLYGON ((441886.851 4466353.213, 441880.171 4...
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (216579, 24)

# %%
df.iloc[2100].geometry

# %%
df.plot(figsize=(30,30))
# Out:
# <AxesSubplot:>

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#     MAPA  DELEGACIO  MUNICIPIO   MASA     HOJA TIPO PARCELA      COORX  \
# 0  28267         28        900  59850  VK4758F    U      22  445749.81
# 1  28267         28        900  59850  VK4758F    U      23  445745.83
# 2  28267         28        900  65223  VK4762D    U      01  446416.88
# 3  28267         28        900  65223  VK4762D    U      01  446416.80
# 4  28267         28        900  19679  VK4616H    U      03  441604.07
#
#         COORY      VIA  NUMERO NUMERODUP  NUMSYMBOL    AREA  FECHAALTA  \
# 0  4478275.61     84.0     6.0      None          6    1029   20130220
# 1  4478250.67   9221.0     1.0      None          6    1022   20130220
# 2  4472079.00   1960.0   239.0      None          6  110052   20130307
# 3  4472079.07   1960.0   239.0      None          6  110108   20130307
# 4  4466408.99  46283.0     1.0      None          6  126843   20130523
#
#    FECHABAJA     NINTERNO    PCAT1    PCAT2 EJERCICIO NUM_EXP CONTROL  \
# 0   20130513  280113239.0  5985022  VK4758F      None    None    None
# 1   20130513  280113240.0  5985023  VK4758F      None    None    None
# 2   20130307  280705779.0  6522301  VK4762D      None    None    None
# 3   99999999  280706924.0  6522301  VK4762D      None    None    None
# 4   20150512  281860670.0  1967903  VK4616H      None    None    None
#
#            REFCAT                                           geometry
# 0  5985022VK4758F  POLYGON ((445726.762 4478263.288, 445727.344 4...
# 1  5985023VK4758F  POLYGON ((445751.268 4478262.563, 445751.476 4...
# 2  6522301VK4762D  POLYGON ((446354.900 4472297.255, 446355.396 4...
# 3  6522301VK4762D  POLYGON ((446311.187 4472177.764, 446312.670 4...
# 4  1967903VK4616H  POLYGON ((441886.851 4466353.213, 441880.171 4...
